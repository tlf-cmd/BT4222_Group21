# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

# %%
# url = "https://www.wunderground.com/history/monthly/sg/WSSS/date/2022-4"
url = "http://www.weather.gov.sg/climate-historical-daily/"

driver = webdriver.Chrome('/Users/yongler/chromedriver_mac64/chromedriver')
driver.get(url)

time.sleep(5)
# search = driver.find_element_by_xpath('//*[@id="inner-content"]/div[2]/div[1]/div[5]/div[1]/div/lib-city-history-observation/div/div[2]/table')

thead = search.find_element_by_xpath(".//thead")
# Extract the table headers (column names)
headers = [header.text.strip() for header in thead.find_elements_by_xpath(".//tr")]


# print(f"HEADERS: {headers}")
# # Find the tbody element (daily weather data)
# tbody = search.find_element_by_xpath(".//tbody")

# for row in tbody.find_elements_by_xpath(".//tr"):
#     data = [cell.text.strip() for cell in row.find_elements_by_xpath(".//td")]
#     if len(data) > 0:

# # Print the weather data
# print(f"DATA: ")
# for row in rows:
#     print(row)

# Close the browser
driver.quit()
# Out:
# /var/folders/27/xh3tm0h964n5gjzv1brx5vrc0000gn/T/ipykernel_26707/1193165491.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/yongler/chromedriver_mac64/chromedriver')
# /var/folders/27/xh3tm0h964n5gjzv1brx5vrc0000gn/T/ipykernel_26707/1193165491.py:7: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search = driver.find_element_by_xpath('//*[@id="inner-content"]/div[2]/div[1]/div[5]/div[1]/div/lib-city-history-observation/div/div[2]/table')
# HEADERS: ['Time Temperature (°F) Dew Point (°F) Humidity (%) Wind Speed (mph) Pressure (in) Precipitation (in)']
# DATA:
# ...
